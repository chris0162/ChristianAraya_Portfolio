# %% [markdown]
# Google Colaboratory file

# %% [markdown]
# Data exploration

# %% [markdown]
# training_set_labels = es el conjunto target para el entrenamiento

# %%
import pandas as pd

# %%
# target de entrenamiento 

df = pd.read_csv('/training_set_labels.csv')
df.columns
# Out:
# Index(['respondent_id', 'h1n1_vaccine', 'seasonal_vaccine'], dtype='object')
